# %%
# !pip install -r requirement.txt

# %%
# !python main.py
# %run visualize_results.py
# Out:
# Loading stories...
# Total stories loaded: 30
# Refining stories through Planner and Critic Agents...
# Saving refined stories...
# Evaluating improvements...
#
# Process completed successfully!
# {'average_raw_score': 71.07, 'average_refined_score': 72.83, 'improvement_percent': 2.49}
#
# 📊 Story Refinement Metrics
# Average Raw Score: 71.07
# Average Refined Score: 72.83
# Improvement: 2.49%
