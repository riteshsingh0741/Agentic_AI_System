# %%
# !python main.py
# %run visualize_results.py
# Out:
# Loading stories...
# Total stories loaded: 30
# Refining stories through Planner and Critic Agents...
# Saving refined stories...
# Evaluating improvements...
#
# Process completed successfully!
# {'average_raw_score': 70.4, 'average_refined_score': 64.0, 'improvement_percent': -9.09}
#
# 📊 Story Refinement Metrics
# Average Raw Score: 70.40
# Average Refined Score: 64.00
# Improvement: -9.09%
